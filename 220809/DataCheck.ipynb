# %%
import DataCheck
import pandas as pd
import numpy as np 

file_name = '220809.xlsx'

raw = pd.read_excel(file_name)
dc = DataCheck.Ready(raw)

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
dc.safreq('SQ1')
# Out:
# ## SQ1 MISSING CHECK
# # All base
# # No error
# ----------

# %%
dc.safreq('SQ2', only=range(15, 80))
# Out:
# ## SQ2 MISSING CHECK
# # All base
# # No error
# ----------
#
# ## SQ2 ANSWER DATA CHECK
# # Answer only in Range 15 THRU 80
# # Only value check : No error
# ----------

# %%
dc.safreq('SQ3', only=range(3, 8))
# Out:
# ## SQ3 MISSING CHECK
# # All base
# # No error
# ----------
#
# ## SQ3 ANSWER DATA CHECK
# # Answer only in Range 3 THRU 8
# # Only value check : No error
# ----------

# %%
ages = {
    3 : [26, 30],
    4 : [31, 35],
    5 : [36, 40],
    6 : [41, 45],
    7 : [46, 50],
    8 : [51, 55]
}
for key, rg in ages.items() :
    dc.logchk(raw.SQ2.between(rg[0], rg[1]), raw.SQ3==key)
# Out:
# ## Puncing Logic Check
# # Puching Logic correct
# ----------
#
#
# ## Puncing Logic Check
# # Puching Logic correct
# ----------
#
#
# ## Puncing Logic Check
# # Puching Logic correct
# ----------
#
#
# ## Puncing Logic Check
# # Puching Logic correct
# ----------
#
#
# ## Puncing Logic Check
# # Puching Logic correct
# ----------
#
#
# ## Puncing Logic Check
# # Puching Logic correct
# ----------

# %%
dc.safreq('SQ4')
# Out:
# ## SQ4 MISSING CHECK
# # All base
# # No error
# ----------

# %%
dc.safreq('SQ5')
# Out:
# ## SQ5 MISSING CHECK
# # All base
# # No error
# ----------

# %%
dc.safreq('SQ6')
# Out:
# ## SQ6 MISSING CHECK
# # All base
# # No error
# ----------

# %%
dc.safreq('SQ6_1', only=range(1, 99), cond=dc.df.SQ6==1)
# Out:
# ## SQ6_1 MISSING CHECK
# # Condition
# # No error
# ----------
#
# ## SQ6_1 ANSWER DATA CHECK
# # Answer only in Range 1 THRU 99
# # Only value check : No error
# ----------

# %%
dc.df['child_age_check'] = dc.df['SQ2'] - 18

# %%
# validate. LIVE CHECK
dc.df[dc.df['child_age_check']<dc.df['SQ6_1']][['record', 'child_age_check', 'SQ6_1']]
# Out:
#     record  child_age_check  SQ6_1
# 0       31               16   92.0
# 3      352               27   93.0
# 5      630               37   85.0
# 6      733               29   71.0
# 8      860               21   98.0
# 12    1876               20   42.0
# 19    2709               24   99.0
# 20    2751               13   70.0
# 21    3132               30   82.0
# 23    3290               16   58.0
# 25    3829               16   64.0
# 27    4514               31   69.0
# 28    4536               32   86.0
# 29    4602               27   62.0
# 30    4679               20   78.0
# 31    4892               22   56.0
# 34    5147               23   86.0
# 36    5393               11   49.0
# 40    6099               14   65.0
# 41    6444               32   49.0
# 42    6743               11   72.0
# 43    7151               22   71.0
# 44    7209               17   34.0
# 48    7790               13   73.0
# 50    8087               10   97.0
# 51    8147               18   86.0
# ...

# %%
dc.safreq('SQ7', only=range(1, 11))
# Out:
# ## SQ7 MISSING CHECK
# # All base
# # No error
# ----------
#
# ## SQ7 ANSWER DATA CHECK
# # Answer only in Range 1 THRU 11
# # Only value check : No error
# ----------

# %%
dc.mafreq(('SQ8r1', 'SQ8r7'))
# Out:
# ## 'SQ8r1 - SQ8r7' Answer Check
# # All base
# # The atleast error check (atleast = 1)
# ----------

# %%
dc.logchk(dc.df.SQ7>=2, dc.df.SQ8r7.isnull())
# Out:
# ## Puncing Logic Check
# # Puching Logic correct
# ----------

# %%
dc.mafreq(('SQ8r1', 'SQ8r7'), cond=dc.df.SQ8r7==7, df=True)
# Out:
#      record  count err  SQ8r1  SQ8r2  SQ8r3  SQ8r4  SQ8r5  SQ8r99  SQ8r7
# 56     9118    1.0          0      0      0      0      0       0    7.0
# 59     9584    1.0          0      0      0      0      0       0    7.0
# 67    11132    1.0          0      0      0      0      0       0    7.0
# 71    11507    1.0          0      0      0      0      0       0    7.0
# 80    12963    1.0          0      0      0      0      0       0    7.0
# 81    13039    1.0          0      0      0      0      0       0    7.0
# 94    15090    1.0          0      0      0      0      0       0    7.0
# 99    15788    1.0          0      0      0      0      0       0    7.0
# 100   15896    1.0          0      0      0      0      0       0    7.0

# %%
dc.logchk(dc.df.SQ7==1, dc.df.SQ8r7==7)
# Out:
# ## Puncing Logic Check
# # Puching Logic correct
# ----------

# %% [markdown]
# # !!! ERROR !!!!
# SQ8r1 : SQ5==2 가 아닐 때도 제시가 되는 중
# SQ8r4 : SQ6==2 일 때 미제시 적용 안돼있음

# %%
dc.safreq('SQ8r1', cond=raw.SQ5==2, with_cols=['SQ5'])
dc.safreq('SQ8r4', cond=raw.SQ6!=2, with_cols=['SQ6'])
# Out:
# ## SQ8r1 MISSING CHECK
# # Condition
# ▶ Error sample count : 65
#
# ## SQ8r4 MISSING CHECK
# # Condition
# ▶ Error sample count : 41

# %%
dc.logchk(dc.df.SQ5!=2, dc.df.SQ8r1.isnull(), err=True, with_cols=['SQ5', 'SQ8r1'])
# Out:
#     record  SQ5  SQ8r1
# 0       31    3      1
# 1      166    1      0
# 2      316    3      0
# 3      352    3      0
# 4      549    1      0
# 6      733    3      0
# 7      803    1      0
# 8      860    1      0
# 9     1205    3      0
# 11    1673    3      0
# 12    1876    1      1
# 13    2148    3      0
# 14    2321    3      0
# 16    2548    3      1
# 18    2683    3      0
# 19    2709    1      0
# 21    3132    3      1
# 22    3287    3      1
# 26    3830    3      1
# 27    4514    3      0
# 30    4679    1      0
# 31    4892    1      0
# 32    4917    3      0
# 33    4979    1      0
# 34    5147    3      0
# 35    5283    1      0
# 36    5393    1      0
# 37    5622    3      0
# 38    5656    1      0
# 42    6743    3      1
# 44    7209    1      0
# 48    7790    1      0
# 50    8087    1      1
# 51    8147    3      1
# 52    8388    1      0
# 54    8860    1      1
# 55    9105    3      0
# 56    9118    3      0
# 57    9491    3      0
# ...

# %%
dc.logchk(dc.df.SQ6==2, dc.df.SQ8r4.isnull(), err=True, with_cols=['SQ6', 'SQ8r1'])
# Out:
#      record  SQ6  SQ8r1
# 1       166    2      0
# 2       316    2      0
# 4       549    2      0
# 7       803    2      0
# 9      1205    2      0
# 10     1270    2      0
# 11     1673    2      0
# 13     2148    2      0
# 15     2480    2      0
# 17     2643    2      0
# 18     2683    2      0
# 24     3723    2      0
# 32     4917    2      0
# 33     4979    2      0
# 35     5283    2      0
# 37     5622    2      0
# 38     5656    2      0
# 39     5950    2      0
# 45     7278    2      1
# 46     7367    2      1
# 47     7637    2      0
# 49     7833    2      0
# 57     9491    2      0
# 58     9518    2      1
# 59     9584    2      0
# 60     9819    2      1
# 64    10346    2      1
# 65    10510    2      1
# 71    11507    2      0
# 74    12456    2      0
# 75    12583    2      0
# 79    12906    2      0
# 81    13039    2      0
# 82    13145    2      1
# 84    13204    2      1
# 90    14486    2      0
# 94    15090    2      0
# ...

# %%
dc.safreq('SQ9')
# Out:
# ## SQ9 MISSING CHECK
# # All base
# # No error
# ----------

# %%
dc.logchk( (dc.df.SQ5.isin([1, 3])) & (dc.df.SQ6==2), dc.df.SQ9==1)
# Out:
# ## Puncing Logic Check
# # Puching Logic correct
# ----------

# %%
dc.logchk( (dc.df.SQ5.isin([2])) & (dc.df.SQ6==2), dc.df.SQ9==2)
# Out:
# ## Puncing Logic Check
# # Puching Logic correct
# ----------

# %%
dc.logchk( (dc.df.SQ6.isin([1, 3])) & (dc.df.SQ6_1.between(0, 6)), dc.df.SQ9==3)
# Out:
# ## Puncing Logic Check
# # Puching Logic correct
# ----------

# %%
dc.logchk( (dc.df.SQ6.isin([1])) & (dc.df.SQ6_1.between(7, 12)), dc.df.SQ9==4)
# Out:
# ## Puncing Logic Check
# # Puching Logic correct
# ----------

# %%
dc.logchk( (dc.df.SQ6.isin([1])) & (dc.df.SQ6_1.between(13, 18)), dc.df.SQ9==5)
# Out:
# ## Puncing Logic Check
# # Puching Logic correct
# ----------

# %%
dc.logchk( (dc.df.SQ6.isin([1])) & (dc.df.SQ6_1 >= 19) & (dc.df.SQ8r4==4), dc.df.SQ9==6)
# Out:
# ## Puncing Logic Check
# # Puching Logic correct
# ----------

# %%
dc.logchk( (dc.df.SQ6.isin([1])) & (dc.df.SQ6_1 >= 19) & (dc.df.SQ8r4!=4), dc.df.SQ9==7)
# Out:
# ## Puncing Logic Check
# # Puching Logic correct
# ----------

# %%
dc.freq('SQ9')
# Out:
# 7    39
# 1    24
# 6    17
# 2    17
# 4     2
# 3     2
# 5     1
# Name: SQ9, dtype: int64

# %%
dc.safreq('SQ10', only=5)
# Out:
# ## SQ10 MISSING CHECK
# # All base
# # No error
# ----------
#
# ## SQ10 ANSWER DATA CHECK
# # Answer only in 5
# # Only value check : No error
# ----------

# %%
dc.safreq('SQ11', only=[1, 2])
# Out:
# ## SQ11 MISSING CHECK
# # All base
# # No error
# ----------
#
# ## SQ11 ANSWER DATA CHECK
# # Answer only in List [1, 2]
# # Only value check : No error
# ----------

# %%
dc.safreq('SQ13', only=range(500000, 30000000))
# Out:
# ## SQ13 MISSING CHECK
# # All base
# # No error
# ----------
#
# ## SQ13 ANSWER DATA CHECK
# # Answer only in Range 500000 THRU 30000000
# # Only value check : No error
# ----------

# %%
dc.safreq('SQ14')
# Out:
# ## SQ14 MISSING CHECK
# # All base
# # No error
# ----------

# %%
dc.df['income_re'] = dc.df['SQ13']/10000
dc.df[['SQ13', 'income_re']]
# Out:
#          SQ13  income_re
# 0     6838621   683.8621
# 1     5593638   559.3638
# 2    17059514  1705.9514
# 3    29518113  2951.8113
# 4    21511803  2151.1803
# 5    19199996  1919.9996
# 6    17381594  1738.1594
# 7    20517245  2051.7245
# 8    15587783  1558.7783
# 9    13495475  1349.5475
# 10   13474853  1347.4853
# 11   26938822  2693.8822
# 12    8127972   812.7972
# 13   10360766  1036.0766
# 14   20639990  2063.9990
# 15    8961220   896.1220
# 16    9514312   951.4312
# 17   23706816  2370.6816
# 18   28226909  2822.6909
# 19   29954418  2995.4418
# 20   14468089  1446.8089
# 21   28046239  2804.6239
# 22   23171224  2317.1224
# 23   21421510  2142.1510
# 24    7269004   726.9004
# 25   26455699  2645.5699
# 26    4432581   443.2581
# 27   20213153  2021.3153
# 28   24552273  2455.2273
# 29    2645896   264.5896
# 30     526869    52.6869
# 31   27062837  2706.2837
# 32   12709154  1270.9154
# 33   11475624  1147.5624
# 34   29655373  2965.5373
# 35   14740166  1474.0166
# ...

# %%
dc.logchk( dc.df.income_re<=249, dc.df.SQ14==1 )
dc.logchk( dc.df.income_re>=1500, dc.df.SQ14==12 )
# Out:
# ## Puncing Logic Check
# # Puching Logic correct
# ----------
#
#
# ## Puncing Logic Check
# # Puching Logic correct
# ----------

# %%
income_range = {
    2 : [250, 299],   
    3 : [300, 349],   
    4 : [350, 399],   
    5 : [400, 499],   
    6 : [500, 599],   
    7 : [600, 699],   
    8 : [700, 799],   
    9 : [800, 899],   
    10 : [900, 999],   
    11 : [1000, 1499]
}

for key, val in income_range.items() :
    print(key)
    dc.logchk( dc.df.income_re.between(val[0], val[1]), dc.df.SQ14==key)
# Out:
# 2
# ## Puncing Logic Check
# # Puching Logic correct
# ----------
#
#
# 3
# ## Puncing Logic Check
# # Puching Logic correct
# ----------
#
#
# 4
# ## Puncing Logic Check
# # Puching Logic correct
# ----------
#
#
# 5
# ## Puncing Logic Check
# # Puching Logic correct
# ----------
#
#
# 6
# ## Puncing Logic Check
# # Puching Logic correct
# ----------
#
#
# 7
# ## Puncing Logic Check
# # Puching Logic correct
# ----------
#
#
# 8
# ## Puncing Logic Check
# # Puching Logic correct
# ----------
#
#
# 9
# ## Puncing Logic Check
# # Puching Logic correct
# ----------
#
#
# 10
# ## Puncing Logic Check
# # Puching Logic correct
# ----------
#
#
# 11
# ## Puncing Logic Check
# # Puching Logic correct
# ----------

# %%
product_codes = list(range(1, 24))

# %%
for p in product_codes :
    dc.safreq(f'SQ15ar{p}', only=[1, 2])
# Out:
# ## SQ15ar1 MISSING CHECK
# # All base
# # No error
# ----------
#
# ## SQ15ar1 ANSWER DATA CHECK
# # Answer only in List [1, 2]
# # Only value check : No error
# ----------
#
#
# ## SQ15ar2 MISSING CHECK
# # All base
# # No error
# ----------
#
# ## SQ15ar2 ANSWER DATA CHECK
# # Answer only in List [1, 2]
# # Only value check : No error
# ----------
#
#
# ## SQ15ar3 MISSING CHECK
# # All base
# # No error
# ----------
#
# ## SQ15ar3 ANSWER DATA CHECK
# # Answer only in List [1, 2]
# # Only value check : No error
# ----------
#
#
# ## SQ15ar4 MISSING CHECK
# # All base
# # No error
# ----------
#
# ## SQ15ar4 ANSWER DATA CHECK
# # Answer only in List [1, 2]
# # Only value check : No error
# ----------
#
#
# ## SQ15ar5 MISSING CHECK
# # All base
# # No error
# ----------
#
# ## SQ15ar5 ANSWER DATA CHECK
# # Answer only in List [1, 2]
# # Only value check : No error
# ----------
#
#
# ## SQ15ar6 MISSING CHECK
# # All base
# # No error
# ----------
#
# ## SQ15ar6 ANSWER DATA CHECK
# ...

# %%
dc.df[ (dc.df.SQ15ar6==2) & (dc.df.SQ15br6==2) ]['record']
# Out:
# Series([], Name: record, dtype: int64)

# %%
for p in product_codes :
    dc.safreq(f'SQ15br{p}', only=[1, 2])
# Out:
# ## SQ15br1 MISSING CHECK
# # All base
# # No error
# ----------
#
# ## SQ15br1 ANSWER DATA CHECK
# # Answer only in List [1, 2]
# # Only value check : No error
# ----------
#
#
# ## SQ15br2 MISSING CHECK
# # All base
# # No error
# ----------
#
# ## SQ15br2 ANSWER DATA CHECK
# # Answer only in List [1, 2]
# # Only value check : No error
# ----------
#
#
# ## SQ15br3 MISSING CHECK
# # All base
# # No error
# ----------
#
# ## SQ15br3 ANSWER DATA CHECK
# # Answer only in List [1, 2]
# # Only value check : No error
# ----------
#
#
# ## SQ15br4 MISSING CHECK
# # All base
# # No error
# ----------
#
# ## SQ15br4 ANSWER DATA CHECK
# # Answer only in List [1, 2]
# # Only value check : No error
# ----------
#
#
# ## SQ15br5 MISSING CHECK
# # All base
# # No error
# ----------
#
# ## SQ15br5 ANSWER DATA CHECK
# # Answer only in List [1, 2]
# # Only value check : No error
# ----------
#
#
# ## SQ15br6 MISSING CHECK
# # All base
# # No error
# ----------
#
# ## SQ15br6 ANSWER DATA CHECK
# ...

# %%
dc.safreq('SQ12', only=[1,2])
# Out:
# ## SQ12 MISSING CHECK
# # All base
# # No error
# ----------
#
# ## SQ12 ANSWER DATA CHECK
# # Answer only in List [1, 2]
# # Only value check : No error
# ----------

# %%
types = [1,2,3,4,5]

# %%
for t in types :
    dc.safreq(f'SQ16r{t}')
# Out:
# ## SQ16r1 MISSING CHECK
# # All base
# # No error
# ----------
#
#
# ## SQ16r2 MISSING CHECK
# # All base
# # No error
# ----------
#
#
# ## SQ16r3 MISSING CHECK
# # All base
# # No error
# ----------
#
#
# ## SQ16r4 MISSING CHECK
# # All base
# # No error
# ----------
#
#
# ## SQ16r5 MISSING CHECK
# # All base
# # No error
# ----------

# %%
dc.count_col('SQ15a_r5_r9', ('SQ15ar5', 'SQ15ar9'), value=1)
# Out:
#      record  SQ15a_r5_r9  SQ15ar5  SQ15ar6  SQ15ar7  SQ15ar8  SQ15ar9
# 0        31          3.0        1        2        1        2        1
# 1       166          2.0        2        1        2        1        2
# 2       316          3.0        1        1        2        2        1
# 3       352          5.0        1        1        1        1        1
# 4       549          2.0        1        1        2        2        2
# 5       630          5.0        1        1        1        1        1
# 6       733          4.0        1        1        1        2        1
# 7       803          3.0        2        2        1        1        1
# 8       860          2.0        2        2        1        2        1
# 9      1205          2.0        1        2        1        2        2
# 10     1270          2.0        1        1        2        2        2
# 11     1673          1.0        2        2        2        2        1
# ...

# %%
for t in types :
    dc.safreq(f'SQ18r{t}', cond=dc.df[f'SQ16r{t}']==1, only=range(1, 5))
# Out:
# ## SQ18r1 MISSING CHECK
# # Condition
# # No error
# ----------
#
# ## SQ18r1 ANSWER DATA CHECK
# # Answer only in Range 1 THRU 5
# # Only value check : No error
# ----------
#
#
# ## SQ18r2 MISSING CHECK
# # Condition
# # No error
# ----------
#
# ## SQ18r2 ANSWER DATA CHECK
# # Answer only in Range 1 THRU 5
# # Only value check : No error
# ----------
#
#
# ## SQ18r3 MISSING CHECK
# # Condition
# # No error
# ----------
#
# ## SQ18r3 ANSWER DATA CHECK
# # Answer only in Range 1 THRU 5
# # Only value check : No error
# ----------
#
#
# ## SQ18r4 MISSING CHECK
# # Condition
# # No error
# ----------
#
# ## SQ18r4 ANSWER DATA CHECK
# # Answer only in Range 1 THRU 5
# # Only value check : No error
# ----------
#
#
# ## SQ18r5 MISSING CHECK
# # Condition
# # No error
# ----------
#
# ## SQ18r5 ANSWER DATA CHECK
# # Answer only in Range 1 THRU 5
# # Only value check : No error
# ----------

# %%
dc.safreq('HQ0')
# Out:
# ## HQ0 MISSING CHECK
# # All base
# # No error
# ----------

# %%
dc.logchk(dc.df.SQ16r2==1, dc.df.HQ0==1)
# Out:
# ## Puncing Logic Check
# # Puching Logic correct
# ----------

# %%
loops = [1,2,3]
base_brand = [1,2,3,4,8,10,11,16,19,20]

# %%
for l in loops :
    dc.safreq(f'SQ19x{l}', cond=dc.df.SQ18r2>=l)
    dc.safreq(f'SQ20x{l}', cond=(dc.df.SQ18r2>=l) & (dc.df[f'SQ19x{l}'].isin(base_brand)))
    dc.df[f'SQ20x{l}_re'] = dc.df[f'SQ20x{l}']//100
    
    print(dc.df[ (dc.df[f'SQ20x{l}_re'] != dc.df[f'SQ19x{l}']) & (dc.df[f'SQ19x{l}'].isin(base_brand)) ][[f'SQ20x{l}_re', f'SQ19x{l}']])
# Out:
# ## SQ19x1 MISSING CHECK
# # Condition
# # No error
# ----------
#
#
# ## SQ20x1 MISSING CHECK
# # Condition
# # No error
# ----------
#
#
# Empty DataFrame
# Columns: [SQ20x1_re, SQ19x1]
# Index: []
# ## SQ19x2 MISSING CHECK
# # Condition
# # No error
# ----------
#
#
# ## SQ20x2 MISSING CHECK
# # Condition
# # No error
# ----------
#
#
# Empty DataFrame
# Columns: [SQ20x2_re, SQ19x2]
# Index: []
# ## SQ19x3 MISSING CHECK
# # Condition
# # No error
# ----------
#
#
# ## SQ20x3 MISSING CHECK
# # Condition
# # No error
# ----------
#
#
# Empty DataFrame
# Columns: [SQ20x3_re, SQ19x3]
# Index: []

# %%
dc.safreq('SQ21r1', only=range(2010, 2021))
dc.safreq('SQ21r2', only=range(1, 12))
# Out:
# ## SQ21r1 MISSING CHECK
# # All base
# # No error
# ----------
#
# ## SQ21r1 ANSWER DATA CHECK
# # Answer only in Range 2010 THRU 2021
# # Only value check : No error
# ----------
#
#
# ## SQ21r2 MISSING CHECK
# # All base
# # No error
# ----------
#
# ## SQ21r2 ANSWER DATA CHECK
# # Answer only in Range 1 THRU 12
# # Only value check : No error
# ----------

# %%
dc.safreq('SQ22', only=range(1, 200), cond=dc.df.HQ0==1)
# Out:
# ## SQ22 MISSING CHECK
# # Condition
# # No error
# ----------
#
# ## SQ22 ANSWER DATA CHECK
# # Answer only in Range 1 THRU 200
# # Only value check : No error
# ----------

# %%
dc.safreq('HQ1', only=1)
# Out:
# ## HQ1 MISSING CHECK
# # All base
# # No error
# ----------
#
# ## HQ1 ANSWER DATA CHECK
# # Answer only in 1
# # Only value check : No error
# ----------

# %%
dc.df[ ['SQ19x1', 'SQ19x2', 'SQ19x3', 'SQ21r1', 'SQ21r2', 'SQ22'] ]
# Out:
#      SQ19x1  SQ19x2  SQ19x3  SQ21r1  SQ21r2  SQ22
# 0         1    11.0    19.0    2020      11    51
# 1         1     NaN     NaN    2020      11    51
# 2         1    19.0     NaN    2020      11    51
# 3         1     NaN     NaN    2020      11    51
# 4         1     8.0     3.0    2020      11    51
# 5         1     NaN     NaN    2020      11    51
# 6         1     1.0    12.0    2020      11    51
# 7         1    17.0     1.0    2020      11    51
# 8         1    10.0    12.0    2020      11    51
# 9         1    15.0    12.0    2020      11    51
# 10        1     6.0     NaN    2020      11    51
# 11        1    14.0     NaN    2020      11    51
# 12        1     NaN     NaN    2020      11    51
# 13        1     6.0    20.0    2020      11    51
# 14        1     3.0    18.0    2020      11    51
# 15        1    10.0     NaN    2020      11    51
# 16        1     NaN     NaN    2020      11    51
# 17        1    14.0     2.0    2020      11    51
# ...

# %%
dc.safreq('SQ23')
# Out:
# ## SQ23 MISSING CHECK
# # All base
# # No error
# ----------

# %%
# dc.df[ ['HQ0', 'SQ18r1', 'SQ18r2', 'SQ23'] ]
dc.logchk(dc.df.HQ0==2, dc.df.SQ23==1)
# Out:
# ## Puncing Logic Check
# ▷ No response to this condition
# ----------

# %%
dc.logchk((dc.df.HQ0==1) & (dc.df.SQ18r1>0) & ~(dc.df.SQ18r2>1), dc.df.SQ23.isin([1, 2, 3, 99]), with_cols=['HQ0', 'SQ18r1', 'SQ18r2', 'SQ23'])
# Out:
# ## Puncing Logic Check
# # Puching Logic correct
# ----------

# %%
dc.logchk((dc.df.HQ0==1) & ~(dc.df.SQ18r1>0) & (dc.df.SQ18r2>1), dc.df.SQ23.isin([1, 4, 5, 99]), with_cols=['HQ0', 'SQ18r1', 'SQ18r2', 'SQ23'])
# Out:
# ## Puncing Logic Check
# # Puching Logic correct
# ----------

# %%
dc.logchk((dc.df.HQ0==1) & (dc.df.SQ18r1>0) & (dc.df.SQ18r2>1), dc.df.SQ23.isin([1, 2, 3, 4, 5, 99]), with_cols=['HQ0', 'SQ18r1', 'SQ18r2', 'SQ23'])
# Out:
# ## Puncing Logic Check
# # Puching Logic correct
# ----------

# %%
dc.safreq('SQ24', cond=dc.df.SQ23.isin([2,3,4,5]))
# Out:
# ## SQ24 MISSING CHECK
# # Condition
# # No error
# ----------

# %%
dc.safreq('SQ25', cond=(dc.df.SQ24.isin([1,2,3, 4, 8, 10, 11, 16, 19, 20])) & ~(dc.df.SQ23.isin([2,3])) , df=True, with_cols=['SQ24'])
# Out:
#     record err only_err    SQ25  SQ24
# 6      733               1001.0  10.0
# 10    1270               1601.0  16.0
# 32    4917               1001.0  10.0
# 41    6444               1699.0  16.0
# 43    7151               1101.0  11.0
# 47    7637                301.0   3.0
# 50    8087               2099.0  20.0
# 56    9118                103.0   1.0
# 61    9923                299.0   2.0
# 63   10262               1699.0  16.0
# 71   11507                201.0   2.0
# 81   13039               1902.0  19.0
# 84   13204               1902.0  19.0

# %%
dc.safreq('SQ26', cond=dc.df.SQ15br6==1, only=range(1, 200))
# Out:
# ## SQ26 MISSING CHECK
# # Condition
# # No error
# ----------
#
# ## SQ26 ANSWER DATA CHECK
# # Answer only in Range 1 THRU 200
# # Only value check : No error
# ----------

# %%
dc.mafreq(('SQ27r1', 'SQ27r99'), cond=dc.df.SQ15br6==1)
# Out:
# ## 'SQ27r1 - SQ27r99' Answer Check
# # Condition
# # The atleast error check (atleast = 1)
# ----------

# %%
dc.safreq('SQ28', cond=dc.df.SQ15br6==1)
# Out:
# ## SQ28 MISSING CHECK
# # Condition
# # No error
# ----------

# %%
dc.masa(('SQ27r1', 'SQ27r99'), 'SQ28')
# Out:
# ## Multi variable base Single variable Logic Check
# # SA : SQ28
# # MA : SQ27r1 - SQ27r99 (21 columns)
# # Logic correct
# ----------

# %%
dc.safreq('SQ29', cond=dc.df.SQ28.isin([1,2,3,4, 8, 10, 11, 16, 19, 20]), with_cols=['SQ28'], df=True)
# Out:
#      record err only_err  SQ29  SQ28
# 0        31                401     4
# 1       166               1902    19
# 2       316               1199    11
# 3       352               1099    10
# 4       549               1699    16
# 5       630                102     1
# 6       733               2001    20
# 7       803                302     3
# 8       860                402     4
# 9      1205                801     8
# 10     1270                105     1
# 11     1673                201     2
# 12     1876               1699    16
# 13     2148                499     4
# 14     2321                899     8
# 15     2480               1601    16
# 16     2548                403     4
# 17     2643               2001    20
# 18     2683               2001    20
# 19     2709               2001    20
# 20     2751                202     2
# 21     3132                102     1
# 22     3287               2099    20
# 23     3290               1902    19
# ...

# %%
dc.safreq('HQ2')
# Out:
# ## HQ2 MISSING CHECK
# # All base
# # No error
# ----------

# %%
dc.logchk( (dc.df.SQ15br6==1) & (dc.df.SQ26>=50) & (dc.df.SQ28.isin([1,2,3,4, 8, 10, 11, 16, 19, 20])), dc.df.HQ2==1)
# Out:
# ## Puncing Logic Check
# # Puching Logic correct
# ----------

# %%
dc.logchk( (dc.df.SQ15br6==1) & (dc.df.SQ26>=50) & (dc.df.SQ28.isin([1,2,3,4, 8, 10, 11, 16, 19, 20])), dc.df.HQ2==1)
# Out:
# ## Puncing Logic Check
# # Puching Logic correct
# ----------

# %%
dc.freq('HQ2')
# Out:
# 1    102
# Name: HQ2, dtype: int64

# %%
dc.safreq('SQ30', cond=dc.df.HQ2==1)
# Out:
# ## SQ30 MISSING CHECK
# # Condition
# # No error
# ----------

# %%
dc.logchk(dc.df.HQ0==2, dc.df.SQ30==1)
# Out:
# ## Puncing Logic Check
# ▷ No response to this condition
# ----------

# %%
dc.logchk((dc.df.HQ0==1) & (dc.df.SQ18r1>0) & ~(dc.df.HQ0==1), dc.df.SQ23.isin([1, 2, 3, 99]), with_cols=['HQ0', 'SQ18r1', 'HQ0', 'SQ30'])
# Out:
# ## Puncing Logic Check
# ▷ No response to this condition
# ----------

# %%
dc.logchk((dc.df.HQ0==1) & ~(dc.df.SQ18r1>0) & (dc.df.HQ0==1), dc.df.SQ23.isin([1, 4, 5, 99]), with_cols=['HQ0', 'SQ18r1', 'HQ0', 'SQ30'])
# Out:
# ## Puncing Logic Check
# # Puching Logic correct
# ----------

# %% [markdown]
# # SQ30 == 5 일 때 SQ31 무응답임

# %%
dc.safreq('SQ31', cond=dc.df.SQ30.isin([2,3,4,5]), with_cols=['SQ30', 'HQ0'], err=True)
# Out:
#      record      err only_err  SQ31  SQ30  HQ0
# 1       166  missing            NaN     5    1
# 5       630  missing            NaN     5    1
# 12     1876  missing            NaN     5    1
# 17     2643  missing            NaN     5    1
# 20     2751  missing            NaN     5    1
# 21     3132  missing            NaN     5    1
# 22     3287  missing            NaN     5    1
# 32     4917  missing            NaN     5    1
# 33     4979  missing            NaN     5    1
# 34     5147  missing            NaN     5    1
# 44     7209  missing            NaN     5    1
# 45     7278  missing            NaN     5    1
# 48     7790  missing            NaN     5    1
# 51     8147  missing            NaN     5    1
# 55     9105  missing            NaN     5    1
# 56     9118  missing            NaN     5    1
# 64    10346  missing            NaN     5    1
# 66    10886  missing            NaN     5    1
# 68    11133  missing            NaN     5    1
# ...

# %%
dc.safreq('SQ32', cond=(dc.df.SQ31.isin([1,2,3,4,8, 10, 11, 16, 19, 20 ])) & ~(dc.df.SQ30.isin([2,3])), df=True, with_cols=['SQ31', 'SQ30'])
# Out:
#     record err only_err    SQ32  SQ31  SQ30
# 0       31               1699.0  16.0     4
# 14    2321               1902.0  19.0     4
# 24    3723                304.0   3.0     4
# 47    7637                201.0   2.0     4
# 58    9518                106.0   1.0     4
# 59    9584               1601.0  16.0     4
# 60    9819                303.0   3.0     4
# 79   12906               1601.0  16.0     4
# 81   13039               1001.0  10.0     4
# 90   14486                899.0   8.0     4

# %%
dc.safreq('HQ3')
# Out:
# ## HQ3 MISSING CHECK
# # All base
# # No error
# ----------

# %%
dc.logchk((dc.df.HQ1==1) & (dc.df.HQ2==2), dc.df.HQ3==1 )
# Out:
# ## Puncing Logic Check
# ▷ No response to this condition
# ----------

# %%
dc.logchk((dc.df.HQ1==1) & (dc.df.HQ2==1), dc.df.HQ3==2 )
# Out:
# ## Puncing Logic Check
# # Puching Logic correct
# ----------

# %%
dc.logchk((dc.df.HQ1==2) & (dc.df.HQ2==1), dc.df.HQ3==3)
# Out:
# ## Puncing Logic Check
# ▷ No response to this condition
# ----------

# %%
dc.freq('HQ3')
# Out:
# 2    102
# Name: HQ3, dtype: int64

# %%
dc.safreq('HQ3_1')
# Out:
# ## HQ3_1 MISSING CHECK
# # All base
# # No error
# ----------

# %%
dc.safreq('HQ3_1')
# Out:
# ## HQ3_1 MISSING CHECK
# # All base
# # No error
# ----------

# %%
dc.logchk( dc.df.HQ3==1, dc.df.HQ3_1==1 )
# Out:
# ## Puncing Logic Check
# ▷ No response to this condition
# ----------

# %%
dc.logchk( dc.df.HQ3==2, dc.df.HQ3_1.isin([1,2]) )
# Out:
# ## Puncing Logic Check
# # Puching Logic correct
# ----------

# %%
dc.logchk( dc.df.HQ3==3, dc.df.HQ3_1.isin([2]) )
# Out:
# ## Puncing Logic Check
# ▷ No response to this condition
# ----------

# %%
dc.freq('HQ3_1')
# Out:
# 2    102
# Name: HQ3_1, dtype: int64

# %%
dc.safreq('HQ3_2')
# Out:
# ## HQ3_2 MISSING CHECK
# # All base
# # No error
# ----------

# %%
#dc.safreq('HQ3_2', cond=(dc.df.SQ30.isin([1,2,3])) & (dc.df.HQ3_1==2) , only=1, err=True, with_cols=['SQ30', 'HQ3_1'])
dc.logchk((dc.df.SQ30.isin([1,2,3])) & (dc.df.HQ3_1==2), dc.df.HQ3_2==1)
# Out:
# ## Puncing Logic Check
# # Puching Logic correct
# ----------

# %%
#dc.safreq('HQ3_2', cond=(dc.df.SQ30.isin([4,5])) & (dc.df.HQ3_1==2) , only=2)
dc.logchk((dc.df.SQ30.isin([4,5])) & (dc.df.HQ3_1==2), dc.df.HQ3_2==2)
# Out:
# ## Puncing Logic Check
# # Puching Logic correct
# ----------

# %%
#dc.safreq('HQ3_2', cond=(dc.df.SQ30==98) & (dc.df.HQ3_1==2) & (dc.df.HQ0==2), only=1)
dc.logchk((dc.df.SQ30==98) & (dc.df.HQ3_1==2), dc.df.HQ3_2==1)
# Out:
# ## Puncing Logic Check
# ▷ No response to this condition
# ----------

# %%
#dc.safreq('HQ3_2', cond=(dc.df.SQ30==98) & (dc.df.HQ3_1==2) & (dc.df.HQ0==1), only=2)
dc.logchk((dc.df.SQ30==98) & (dc.df.HQ3_1==2), dc.df.HQ3_2==2)
# Out:
# ## Puncing Logic Check
# ▷ No response to this condition
# ----------

# %%
dc.safreq('HQ4')
# Out:
# ## HQ4 MISSING CHECK
# # All base
# # No error
# ----------

# %%
dc.df[dc.df['HQ3_1']==1][['HQ4', 'SQ19x1']]
# Out:
# Empty DataFrame
# Columns: [HQ4, SQ19x1]
# Index: []

# %%
dc.df[(dc.df['HQ3_1']==2) & (dc.df.SQ28.isin([1,2,3]))][['HQ4', 'SQ28']]
# Out:
#      HQ4  SQ28
# 5      1     1
# 7      3     3
# 10     1     1
# 11     2     2
# 20     2     2
# 21     1     1
# 26     1     1
# 28     3     3
# 30     1     1
# 31     3     3
# 33     2     2
# 35     1     1
# 36     2     2
# 38     3     3
# 41     2     2
# 43     1     1
# 45     3     3
# 61     3     3
# 62     2     2
# 64     1     1
# 65     2     2
# 66     2     2
# 70     2     2
# 74     2     2
# 76     2     2
# 79     1     1
# 83     3     3
# 85     3     3
# 86     1     1
# 89     3     3
# 90     2     2
# 100    3     3
# 101    2     2

# %%
dc.df[(dc.df['HQ3_1']==2) & ~(dc.df.SQ28.isin([1,2,3]))][['HQ4', 'SQ28']]
# Out:
#     HQ4  SQ28
# 0     4     4
# 1     4    19
# 2     4    11
# 3     4    10
# 4     4    16
# 6     4    20
# 8     4     4
# 9     4     8
# 12    4    16
# 13    4     4
# 14    4     8
# 15    4    16
# 16    4     4
# 17    4    20
# 18    4    20
# 19    4    20
# 22    4    20
# 23    4    19
# 24    4    16
# 25    4    16
# 27    4    19
# 29    4    16
# 32    4    20
# 34    4    16
# 37    4    11
# 39    4    19
# 40    4    11
# 42    4    16
# 44    4    19
# 46    4    20
# 47    4     8
# 48    4     8
# 49    4    10
# 50    4    11
# 51    4    10
# 52    4    10
# 53    4     4
# 54    4    19
# 55    4     8
# 56    4    19
# 57    4    19
# 58    4    10
# 59    4    11
# 60    4    20
# 63    4    19
# 67    4    19
# 68    4    20
# 69    4    19
# 71    4    19
# 72    4    20
# 73    4    11
# 75    4    11
# 77    4    11
# 78    4    16
# 80    4    10
# 81    4    10
# 82    4    19
# 84    4     8
# 87    4    10
# 88    4     4
# 91    4    19
# ...

# %%
dc.safreq('HQ5')
# Out:
# ## HQ5 MISSING CHECK
# # All base
# # No error
# ----------

# %%
dc.df[dc.df.HQ3_1==1][['HQ5','SQ20x1']]
# Out:
# Empty DataFrame
# Columns: [HQ5, SQ20x1]
# Index: []

# %%
dc.df['SQ29_re'] = dc.df['SQ29']//100

# %%
dc.df[(dc.df.HQ3_1==2) & (dc.df.SQ29_re.isin([1,2,3])) ][['HQ5','SQ29']]
# Out:
#      HQ5  SQ29
# 5    102   102
# 7    302   302
# 10   105   105
# 11   201   201
# 20   202   202
# 21   102   102
# 26   107   107
# 28   303   303
# 30   106   106
# 31   302   302
# 33   202   202
# 35   105   105
# 36   201   201
# 38   302   302
# 41   299   299
# 43   110   110
# 45   302   302
# 61   303   303
# 62   201   201
# 64   199   199
# 65   202   202
# 66   202   202
# 70   202   202
# 74   201   201
# 76   201   201
# 79   106   106
# 83   304   304
# 85   301   301
# 86   105   105
# 89   304   304
# 90   299   299
# 100  301   301
# 101  201   201

# %%
dc.safreq('HQ6', cond=dc.df.HQ3_2==2)
# Out:
# ## HQ6 MISSING CHECK
# # Condition
# # No error
# ----------

# %%
dc.safreq('HQ6', cond=dc.df.HQ3_2==2, df=True, with_cols=['HQ3_2', 'SQ19x1'])
# Out:
#      record err only_err  HQ6  HQ3_2  SQ19x1
# 0        31               1.0      2       1
# 1       166               1.0      2       1
# 4       549               1.0      2       1
# 5       630               1.0      2       1
# 7       803               1.0      2       1
# 9      1205               1.0      2       1
# 10     1270               1.0      2       1
# 11     1673               1.0      2       1
# 12     1876               1.0      2       1
# 14     2321               1.0      2       1
# 15     2480               1.0      2       1
# 17     2643               1.0      2       1
# 19     2709               1.0      2       1
# 20     2751               1.0      2       1
# 21     3132               1.0      2       1
# 22     3287               1.0      2       1
# 23     3290               1.0      2       1
# 24     3723               1.0      2       1
# 25     3829               1.0      2       1
# 28     4536               1.0      2       1
# ...

# %% [markdown]
# # AQ1 PASS

# %%
dc.mafreq(('AQ2r1', 'AQ2r99'))
# Out:
# ## 'AQ2r1 - AQ2r99' Answer Check
# # All base
# # The atleast error check (atleast = 1)
# ----------

# %%
dc.mafreq(('AQ2r1', 'AQ2r99'), cond=dc.df.HQ3_1==2, with_cols=['SQ28'])
# Out:
# ## 'AQ2r1 - AQ2r99' Answer Check
# # Condition
# # The atleast error check (atleast = 1)
# ----------

# %%
dc.mafreq(('AQ2r1', 'AQ2r99'), cond=dc.df.HQ3_1==1)
# Out:
# ## 'AQ2r1 - AQ2r99' Answer Check
# # Condition
# # The atleast error check (atleast = 1)
# ▷ No response to this condition
# ▶ Error sample count : 102
# ----------

# %% [markdown]
# # AQ4 PASS

# %% [markdown]
# # CBC PASS

# %%
dc.safreq('CQ1', cond=~(dc.df.HQ3_1==2) | ~(dc.df.SQ30==1))
# Out:
# ## CQ1 MISSING CHECK
# # Condition
# # No error
# ----------

# %% [markdown]
# ### HQ3_1 == 2 & SQ30 == 1 인 케이스 무응답인데 이건 로직 자체를 확인할 필요가 있을 듯

# %%
dc.safreq('CQ2', cond=~((dc.df.HQ3_1==1) & (dc.df.SQ30==1)), with_cols=['HQ3_1', 'SQ30'], only=range(0, 90))
# Out:
# ## CQ2 MISSING CHECK
# # Condition
# ▶ Error sample count : 26
# ## CQ2 ANSWER DATA CHECK
# # Answer only in Range 0 THRU 90
# ▶ Only Error sample count : 26

# %%
dc.safreq('CQ5r1', cond=~((dc.df.HQ3_1==1) & (dc.df.SQ30==1)), only=range(0, 100))
# Out:
# ## CQ5r1 MISSING CHECK
# # Condition
# ▶ Error sample count : 26
# ## CQ5r1 ANSWER DATA CHECK
# # Answer only in Range 0 THRU 100
# ▶ Only Error sample count : 26

# %%
dc.safreq('CQ5r2', cond=~((dc.df.HQ3_1==1) & (dc.df.SQ30==1)), only=range(0, 100))
# Out:
# ## CQ5r2 MISSING CHECK
# # Condition
# ▶ Error sample count : 26
# ## CQ5r2 ANSWER DATA CHECK
# # Answer only in Range 0 THRU 100
# ▶ Only Error sample count : 26

# %%
dc.mafreq(('CQ7c1', 'CQ7c5'))
# Out:
# ## 'CQ7c1 - CQ7c5' Answer Check
# # All base
# # The atleast error check (atleast = 1)
# ----------

# %%
nz = list(range(1, 9))

# %%
for n in nz :
    dc.safreq(f'CQ10n{n}', cond=(dc.df.HQ3_1==1) | (dc.df.HQ3_2==2))
# Out:
# ## CQ10n1 MISSING CHECK
# # Condition
# # No error
# ----------
#
#
# ## CQ10n2 MISSING CHECK
# # Condition
# # No error
# ----------
#
#
# ## CQ10n3 MISSING CHECK
# # Condition
# # No error
# ----------
#
#
# ## CQ10n4 MISSING CHECK
# # Condition
# # No error
# ----------
#
#
# ## CQ10n5 MISSING CHECK
# # Condition
# # No error
# ----------
#
#
# ## CQ10n6 MISSING CHECK
# # Condition
# # No error
# ----------
#
#
# ## CQ10n7 MISSING CHECK
# # Condition
# # No error
# ----------
#
#
# ## CQ10n8 MISSING CHECK
# # Condition
# # No error
# ----------

# %%
for n in nz :
    dc.safreq(f'CQ11n{n}', cond= dc.df[f'CQ10n{n}']==1)
# Out:
# ## CQ11n1 MISSING CHECK
# # Condition
# # No error
# ----------
#
#
# ## CQ11n2 MISSING CHECK
# # Condition
# # No error
# ----------
#
#
# ## CQ11n3 MISSING CHECK
# # Condition
# # No error
# ----------
#
#
# ## CQ11n4 MISSING CHECK
# # Condition
# # No error
# ----------
#
#
# ## CQ11n5 MISSING CHECK
# # Condition
# # No error
# ----------
#
#
# ## CQ11n6 MISSING CHECK
# # Condition
# # No error
# ----------
#
#
# ## CQ11n7 MISSING CHECK
# # Condition
# # No error
# ----------
#
#
# ## CQ11n8 MISSING CHECK
# # Condition
# # No error
# ----------

# %%
for n in nz :
    dc.safreq(f'CQ12n{n}', cond= dc.df[f'CQ10n{n}']==1, only=range(0, 100))
# Out:
# ## CQ12n1 MISSING CHECK
# # Condition
# # No error
# ----------
#
# ## CQ12n1 ANSWER DATA CHECK
# # Answer only in Range 0 THRU 100
# # Only value check : No error
# ----------
#
#
# ## CQ12n2 MISSING CHECK
# # Condition
# # No error
# ----------
#
# ## CQ12n2 ANSWER DATA CHECK
# # Answer only in Range 0 THRU 100
# # Only value check : No error
# ----------
#
#
# ## CQ12n3 MISSING CHECK
# # Condition
# # No error
# ----------
#
# ## CQ12n3 ANSWER DATA CHECK
# # Answer only in Range 0 THRU 100
# # Only value check : No error
# ----------
#
#
# ## CQ12n4 MISSING CHECK
# # Condition
# # No error
# ----------
#
# ## CQ12n4 ANSWER DATA CHECK
# # Answer only in Range 0 THRU 100
# # Only value check : No error
# ----------
#
#
# ## CQ12n5 MISSING CHECK
# # Condition
# # No error
# ----------
#
# ## CQ12n5 ANSWER DATA CHECK
# # Answer only in Range 0 THRU 100
# # Only value check : No error
# ----------
#
#
# ## CQ12n6 MISSING CHECK
# # Condition
# # No error
# ----------
#
# ...

# %%
dc.sum_col('CQ12_sum', ('CQ12n1', 'CQ12n8'), cond=(dc.df.HQ3_1==1) | (dc.df.HQ3_2==2))
# Out:
#      record  CQ12_sum  CQ12n1  CQ12n2  CQ12n3  CQ12n4  CQ12n5  CQ12n6  CQ12n7  \
# 0        31     100.0     NaN     1.0    44.0    25.0     7.0     NaN    23.0
# 1       166     100.0     NaN     NaN     NaN     NaN    83.0    17.0     NaN
# 2       316       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3       352       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4       549     100.0     NaN     NaN    31.0     6.0    41.0    20.0     2.0
# 5       630     100.0    10.0     NaN     NaN     9.0    28.0    25.0    28.0
# 6       733       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 7       803     100.0     7.0     NaN     NaN    19.0     NaN    71.0     NaN
# 8       860       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 9      1205     100.0     NaN     NaN     NaN     NaN     6.0     NaN    94.0
# 10     1270     100.0     NaN   100.0     NaN     NaN     NaN     NaN     NaN
# ...

# %%
# dc.df[(dc.df.HQ3_1==1) | (dc.df.HQ3_2==2)]['CQ12_sum']
dc.safreq('CQ12_sum', cond=(dc.df.HQ3_1==1) | (dc.df.HQ3_2==2), only=100, with_cols=['HQ3_1', 'HQ3_2'] + [f'CQ10n{n}' for n in nz], err=True)
# Out:
#     record err only_err  CQ12_sum  HQ3_1  HQ3_2  CQ10n1  CQ10n2  CQ10n3  \
# 68   11133          chk       0.0      2      2     2.0     2.0     2.0
#
#     CQ10n4  CQ10n5  CQ10n6  CQ10n7  CQ10n8
# 68     2.0     2.0     2.0     2.0     2.0

# %%
dc.safreq('CQ13')
# Out:
# ## CQ13 MISSING CHECK
# # All base
# # No error
# ----------

# %%
dc.safreq('CQ14x1')
dc.safreq('CQ14x2')
dc.safreq('CQ14x3')
# Out:
# ## CQ14x1 MISSING CHECK
# # All base
# # No error
# ----------
#
#
# ## CQ14x2 MISSING CHECK
# # All base
# # No error
# ----------
#
#
# ## CQ14x3 MISSING CHECK
# # All base
# # No error
# ----------

# %%
dc.safreq('CQ15x1')
dc.safreq('CQ15x2')
dc.safreq('CQ15x3')
# Out:
# ## CQ15x1 MISSING CHECK
# # All base
# # No error
# ----------
#
#
# ## CQ15x2 MISSING CHECK
# # All base
# # No error
# ----------
#
#
# ## CQ15x3 MISSING CHECK
# # All base
# # No error
# ----------

# %%
dc.safreq('CQ16r1')
dc.safreq('CQ16r3')
dc.safreq('CQ16r6')
dc.safreq('CQ16r8')
dc.safreq('CQ16r12')
# Out:
# ## CQ16r1 MISSING CHECK
# # All base
# # No error
# ----------
#
#
# ## CQ16r3 MISSING CHECK
# # All base
# # No error
# ----------
#
#
# ## CQ16r6 MISSING CHECK
# # All base
# # No error
# ----------
#
#
# ## CQ16r8 MISSING CHECK
# # All base
# # No error
# ----------
#
#
# ## CQ16r12 MISSING CHECK
# # All base
# # No error
# ----------

# %%
dc.safreq('CQ17r1')
dc.safreq('CQ17r2')
# Out:
# ## CQ17r1 MISSING CHECK
# # All base
# # No error
# ----------
#
#
# ## CQ17r2 MISSING CHECK
# # All base
# # No error
# ----------

# %%
dc.safreq('CQ18')
# Out:
# ## CQ18 MISSING CHECK
# # All base
# # No error
# ----------

# %%
dc.safreq('CQ19r1')
dc.safreq('CQ19r2')
dc.safreq('CQ19r3')
# Out:
# ## CQ19r1 MISSING CHECK
# # All base
# # No error
# ----------
#
#
# ## CQ19r2 MISSING CHECK
# # All base
# # No error
# ----------
#
#
# ## CQ19r3 MISSING CHECK
# # All base
# # No error
# ----------

# %%
dc.safreq('CQ20r1')
dc.safreq('CQ20r2')
dc.safreq('CQ20r3')
dc.safreq('CQ20r4')
dc.safreq('CQ20r5')
dc.safreq('CQ20r6')
# Out:
# ## CQ20r1 MISSING CHECK
# # All base
# # No error
# ----------
#
#
# ## CQ20r2 MISSING CHECK
# # All base
# # No error
# ----------
#
#
# ## CQ20r3 MISSING CHECK
# # All base
# # No error
# ----------
#
#
# ## CQ20r4 MISSING CHECK
# # All base
# # No error
# ----------
#
#
# ## CQ20r5 MISSING CHECK
# # All base
# # No error
# ----------
#
#
# ## CQ20r6 MISSING CHECK
# # All base
# # No error
# ----------

# %%
dc.mafreq(('DQ1r1', 'DQ1r9'))
# Out:
# ## 'DQ1r1 - DQ1r9' Answer Check
# # All base
# # The atleast error check (atleast = 1)
# ----------

# %%
dc.safreq('DQ2r1', cond=dc.df.DQ1r1==1, only=range(1, 10))
dc.safreq('DQ2r2', cond=dc.df.DQ1r1==2, only=range(1, 10))
# Out:
# ## DQ2r1 MISSING CHECK
# # Condition
# # No error
# ----------
#
# ## DQ2r1 ANSWER DATA CHECK
# # Answer only in Range 1 THRU 10
# # Only value check : No error
# ----------
#
#
# ## DQ2r2 MISSING CHECK
# # Condition
# ▷ No response to this condition
# ▶ Error sample count : 31
# ## DQ2r2 ANSWER DATA CHECK
# # Answer only in Range 1 THRU 10
# # Only value check : No error
# ----------

# %%
dc.df['DQ2_sum'] = dc.df['DQ2r1'].fillna(0) + dc.df['DQ2r2'].fillna(0)
dc.df[['DQ2_sum', 'DQ2r1', 'DQ2r2']]
# Out:
#      DQ2_sum  DQ2r1  DQ2r2
# 0        0.0    NaN    NaN
# 1       10.0   10.0    NaN
# 2       10.0    NaN   10.0
# 3        0.0    NaN    NaN
# 4        4.0    4.0    NaN
# 5        0.0    NaN    NaN
# 6        3.0    NaN    3.0
# 7        0.0    NaN    NaN
# 8        0.0    NaN    NaN
# 9        0.0    NaN    NaN
# 10       6.0    6.0    NaN
# 11       5.0    NaN    5.0
# 12       0.0    NaN    NaN
# 13       1.0    1.0    NaN
# 14       3.0    NaN    3.0
# 15       6.0    6.0    NaN
# 16       0.0    NaN    NaN
# 17       0.0    NaN    NaN
# 18       4.0    NaN    4.0
# 19       4.0    NaN    4.0
# 20       0.0    NaN    NaN
# 21       1.0    NaN    1.0
# 22       6.0    6.0    NaN
# 23       0.0    NaN    NaN
# 24       6.0    2.0    4.0
# 25       0.0    NaN    NaN
# 26       0.0    NaN    NaN
# 27       0.0    NaN    NaN
# 28       4.0    NaN    4.0
# 29       2.0    2.0    NaN
# 30       9.0    9.0    NaN
# 31       0.0    NaN    NaN
# 32      10.0    NaN   10.0
# ...

# %%
dc.safreq('DQ3c1', cond=dc.df.DQ2_sum>=1, with_cols=['DQ2_sum'])
# Out:
# ## DQ3c1 MISSING CHECK
# # Condition
# # No error
# ----------

# %%
dc.safreq('DQ3c2', cond=dc.df.DQ2_sum>=2)
# Out:
# ## DQ3c2 MISSING CHECK
# # Condition
# # No error
# ----------

# %%
dc.safreq('DQ3c3', cond=dc.df.DQ2_sum>=3)
# Out:
# ## DQ3c3 MISSING CHECK
# # Condition
# # No error
# ----------

# %%
dc.safreq('DQ3c4', cond=dc.df.DQ2_sum>=4)
# Out:
# ## DQ3c4 MISSING CHECK
# # Condition
# # No error
# ----------

# %%
dc.safreq('DQ3c5', cond=dc.df.DQ2_sum>=5)
# Out:
# ## DQ3c5 MISSING CHECK
# # Condition
# # No error
# ----------

# %%
#dc.safreq('HQ7', cond=(dc.df.DQ1r1==1) | (dc.df.DQ1r2==2), only=1, err=True)
dc.logchk((dc.df.DQ1r1==1) | (dc.df.DQ1r2==2), dc.df.HQ7==1)
# Out:
# ## Puncing Logic Check
# # Puching Logic correct
# ----------

# %%
#dc.safreq('HQ7', cond=~((dc.df.DQ1r1==1) | (dc.df.DQ1r2==2)), only=2)
dc.logchk(~((dc.df.DQ1r1==1) | (dc.df.DQ1r2==2)), dc.df.HQ7==2)
# Out:
# ## Puncing Logic Check
# # Puching Logic correct
# ----------

# %%
dc.safreq('DQ4')
# Out:
# ## DQ4 MISSING CHECK
# # All base
# # No error
# ----------

# %%
dc.safreq('DQ5', cond=dc.df.SQ8r1==1)
# Out:
# ## DQ5 MISSING CHECK
# # Condition
# # No error
# ----------

# %%
dc.safreq('DQ6')
# Out:
# ## DQ6 MISSING CHECK
# # All base
# # No error
# ----------

# %%
dc.safreq('DQ7')
# Out:
# ## DQ7 MISSING CHECK
# # All base
# # No error
# ----------

# %%
dc.safreq('DQ8', only=range(5, 100))
# Out:
# ## DQ8 MISSING CHECK
# # All base
# # No error
# ----------
#
# ## DQ8 ANSWER DATA CHECK
# # Answer only in Range 5 THRU 100
# # Only value check : No error
# ----------
