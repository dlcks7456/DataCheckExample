# %%
import DataCheck
import pandas as pd

file_name = '220813.xlsx'

raw = pd.read_excel(file_name)
dc = DataCheck.Ready(raw)

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
dc.safreq('SQ1')
# Out:
# ## SQ1 MISSING CHECK
# - answer is not missing
# ----------

# %%
# sst = 0
dc.mafreq(('SQ2r1', 'SQ2r98'), df=True)
# Out:
#      record  count  SQ2r1  SQ2r2  SQ2r3  SQ2r4  SQ2r5  SQ2r6  SQ2r7  SQ2r98
# 0         3      2      0      0      0      0      5      6      0       0
# 1         2      2      1      0      0      4      0      0      0       0
# 2         8      1      1      0      0      0      0      0      0       0
# 3        11      1      0      2      0      0      0      0      0       0
# 4        15      1      1      0      0      0      0      0      0       0
# 5        16      1      0      0      0      4      0      0      0       0
# 6        17      4      1      0      0      4      5      6      0       0
# 7        21      1      0      0      3      0      0      0      0       0
# 8        22      1      0      2      0      0      0      0      0       0
# 9        23      1      0      0      3      0      0      0      0       0
# 10       25      5      1      0      3      0      5      6      7       0
# ...

# %%
dc.safreq('SQ3', only=2)
# Out:
# ## SQ3 ANSWER DATA CHECK
# # available answer = 2
# - answer is not error
# ----------

# %%
dc.safreq('SQ4', only=1)
# Out:
# ## SQ4 ANSWER DATA CHECK
# # available answer = 1
# - answer is not error
# ----------

# %%
dc.safreq('SQ5', only=[1, 2])
# Out:
# ## SQ5 ANSWER DATA CHECK
# # available answer = [1 THRU 2]
# - answer is not error
# ----------

# %%
dc.safreq('SQ6')
# Out:
# ## SQ6 MISSING CHECK
# - answer is not missing
# ----------

# %%
dc.safreq('SQ7', only=range(18, 44))
dc.safreq('SQ7', cond=dc.df.SQ5==1,only=range(18, 29), df=True)
#dc.safreq('SQ7', cond=dc.df.SQ5==2,only=range(30, 44))
# Out:
# ## SQ7 ANSWER DATA CHECK
# # available answer = [18 THRU 44]
# - answer is not error
# ----------
#      record  SQ7
# 0         3   21
# 5        16   23
# 12       27   26
# 13       28   19
# 18       39   23
# 22       48   27
# 23       51   29
# 24       52   28
# 31       69   27
# 38       81   27
# 39       82   27
# 41       86   28
# 47       97   28
# 48       99   22
# 49      100   18
# 51      102   21
# 52      104   22
# 53      105   25
# 54      108   20
# 55      109   21
# 57      111   23
# 68      127   20
# 69      130   27
# 73      137   19
# 75      141   25
# 76      143   25
# 79      147   27
# 80      150   27
# 81      156   29
# 91      173   23
# 95      177   25
# 96      178   29
# 97      180   21
# 98      181   19
# 100     185   19
# 101     186   24
# 103     189   24
# 105     197   21
# 107     199   23
# 109     205   25
# 110     206   29
# 111     207   19
# 112     208   20
# 113     209   18
# 115     211   23
# 118     216   23
# ...

# %%
dc.safreq('SQ7', cond=dc.df.SQ5==1,only=range(18, 29), df=True, with_cols=['SQ5'])
# Out:
#      record  SQ7  SQ5
# 0         3   21    1
# 5        16   23    1
# 12       27   26    1
# 13       28   19    1
# 18       39   23    1
# 22       48   27    1
# 23       51   29    1
# 24       52   28    1
# 31       69   27    1
# 38       81   27    1
# 39       82   27    1
# 41       86   28    1
# 47       97   28    1
# 48       99   22    1
# 49      100   18    1
# 51      102   21    1
# 52      104   22    1
# 53      105   25    1
# 54      108   20    1
# 55      109   21    1
# 57      111   23    1
# 68      127   20    1
# 69      130   27    1
# 73      137   19    1
# 75      141   25    1
# 76      143   25    1
# 79      147   27    1
# 80      150   27    1
# 81      156   29    1
# 91      173   23    1
# 95      177   25    1
# 96      178   29    1
# 97      180   21    1
# 98      181   19    1
# 100     185   19    1
# 101     186   24    1
# 103     189   24    1
# 105     197   21    1
# 107     199   23    1
# 109     205   25    1
# ...

# %%
dc.safreq('SQ7', cond=dc.df.SQ5==2,only=range(30, 44), df=True, with_cols=['SQ5'])
# Out:
#      record  SQ7  SQ5
# 1         2   39    2
# 2         8   38    2
# 3        11   44    2
# 4        15   32    2
# 6        17   32    2
# 7        21   41    2
# 8        22   38    2
# 9        23   35    2
# 10       25   34    2
# 11       26   33    2
# 14       30   37    2
# 15       31   30    2
# 16       33   31    2
# 17       38   35    2
# 19       42   41    2
# 20       46   43    2
# 21       47   38    2
# 25       53   40    2
# 26       56   38    2
# 27       57   32    2
# 28       58   42    2
# 29       62   34    2
# 30       66   39    2
# 32       70   42    2
# 33       71   37    2
# 34       74   42    2
# 35       76   42    2
# 36       78   36    2
# 37       80   34    2
# 40       83   31    2
# 42       87   39    2
# 43       88   35    2
# 44       91   42    2
# 45       92   42    2
# 46       94   40    2
# 50      101   35    2
# 56      110   41    2
# 58      112   37    2
# 59      113   35    2
# 60      115   34    2
# ...

# %%
for x in [1, 2] :
    dc.safreq(f'SQ8r{x}', cond=dc.df.SQ5==2)
# Out:
# ## SQ8r1 MISSING CHECK
# - answer is not missing
# ----------
#
# ## SQ8r2 MISSING CHECK
# - answer is not missing
# ----------

# %%
# dc.safreq('SQ8r1', cond=dc.df.SQ5==2, df=True, with_cols=['SQ8r2'])
# dc.mafreq(('SQ8r1', 'SQ8r2'), cond=dc.df.SQ5==2, df=True)
dc.mafreq(('SQ8r1', 'SQ8r2'), cond=dc.df.SQ5==2)
# Out:
# ## 'SQ8r1 - SQ8r2' Answer Check
# # Answer count check
# # atleast error check (atleast = 1)
# atleast - answer is not error
#
# ----------

# %%
dc.safreq('Q1', only=range(1, 5))
# Out:
# ## Q1 ANSWER DATA CHECK
# # available answer = [1 THRU 5]
# - answer is not error
# ----------

# %%
dc.mafreq(('Q2r1', 'Q2r98'))
dc.mafreq(('Q2r1', 'Q2r98'), df=True)
# Out:
# ## 'Q2r1 - Q2r98' Answer Check
# # Answer count check
# # atleast error check (atleast = 1)
# atleast - answer is not error
#
# ----------
#      record  count  Q2r1  Q2r2  Q2r3  Q2r4  Q2r5  Q2r6  Q2r7  Q2r8  Q2r9  \
# 0         3      5     0     2     3     4     0     0     7     0     9
# 1         2      4     1     0     0     0     0     0     7     8     9
# 2         8      5     0     0     3     0     5     0     7     0     9
# 3        11      6     1     0     0     0     5     0     7     8     9
# 4        15      6     1     0     0     0     0     6     7     0     9
# 5        16      5     0     2     0     0     5     0     7     0     9
# 6        17      6     1     0     0     4     0     6     7     0     9
# 7        21      3     0     0     0     0     5     0     7     0     9
# 8        22      6     1     0     0     4     0     0     7     0     9
# 9        23      6     1     0     3     0     0     0     7     0     9
# ...

# %%
dc.safreq('Q2r7', only=7)
dc.safreq('Q2r9', only=9)
# Out:
# ## Q2r7 ANSWER DATA CHECK
# # available answer = 7
# - answer is not error
# ----------
#
# ## Q2r9 ANSWER DATA CHECK
# # available answer = 9
# - answer is not error
# ----------

# %%
bc = [1, 2, 3, 4, 5, 6]

# %%
dc.mafreq([f'Q3x1b{b}' for b in bc])
# Out:
# ## 'Q3x1b1 - Q3x1b6' Answer Check
# # Answer count check
# # atleast error check (atleast = 1)
# atleast - answer is not error
#
# ----------

# %%
for b in bc :
    dc.safreq(f'Q3x2b{b}', only=range(1, 99), cond=dc.df[f'Q3x1b{b}']==b)
# Out:
# ## Q3x2b1 ANSWER DATA CHECK
# # available answer = [1 THRU 99]
# - answer is not error
# ----------
#
# ## Q3x2b2 ANSWER DATA CHECK
# # available answer = [1 THRU 99]
# - answer is not error
# ----------
#
# ## Q3x2b3 ANSWER DATA CHECK
# # available answer = [1 THRU 99]
# - answer is not error
# ----------
#
# ## Q3x2b4 ANSWER DATA CHECK
# # available answer = [1 THRU 99]
# - answer is not error
# ----------
#
# ## Q3x2b5 ANSWER DATA CHECK
# # available answer = [1 THRU 99]
# - answer is not error
# ----------
#
# ## Q3x2b6 ANSWER DATA CHECK
# # available answer = [1 THRU 99]
# - answer is not error
# ----------

# %%
dc.safreq('HQ3')
# Out:
# ## HQ3 MISSING CHECK
# - answer is not missing
# ----------

# %%
dc.freq('HQ3')
# Out:
# 1    52
# 4    47
# 2    45
# 3    42
# 6    42
# 5    30
# Name: HQ3, dtype: int64

# %%
Q3x2 = [f'Q3x2b{b}' for b in bc]

# %%
# max
dc.df['Q3x2_max'] = dc.df[Q3x2].max(axis=1)

# %%
cols = Q3x2 + ['Q3x2_max']
dc.df[cols]
# Out:
#      Q3x2b1  Q3x2b2  Q3x2b3  Q3x2b4  Q3x2b5  Q3x2b6  Q3x2_max
# 0       NaN    86.0     NaN     NaN     NaN     NaN      86.0
# 1      10.0     NaN     NaN     NaN     NaN     NaN      10.0
# 2       NaN     NaN    60.0     NaN    26.0     NaN      60.0
# 3       NaN     NaN     NaN     NaN    73.0     NaN      73.0
# 4       NaN     NaN     NaN     NaN    15.0     NaN      15.0
# 5      50.0     NaN    66.0     NaN    36.0     NaN      66.0
# 6       NaN     NaN     NaN    75.0     NaN     NaN      75.0
# 7      94.0     NaN     NaN     NaN     NaN     NaN      94.0
# 8       NaN     NaN    17.0     NaN     NaN     NaN      17.0
# 9      58.0     NaN     NaN     NaN     NaN     NaN      58.0
# 10      NaN     NaN     NaN     NaN     6.0     NaN       6.0
# 11     29.0     NaN    68.0     NaN     NaN    36.0      68.0
# 12      NaN     NaN    55.0     NaN     NaN     5.0      55.0
# 13      NaN     NaN     1.0     NaN    40.0     NaN      40.0
# ...

# %%
# HQ3 logic check
idxs = list(dc.df.index)
for idx in idxs :
    max_value = dc.df.loc[idx, 'Q3x2_max']
    HQ3_value = dc.df.loc[idx, 'HQ3']
    base_qid = f'Q3x2b{HQ3_value}'
    base_value = dc.df.loc[idx, base_qid]
    if not max_value == base_value :
        print(list(dc.df.loc[idx, ['record', base_qid, 'Q3x2_max']]))

# %%
dc.safreq('Q4r1', only=range(0, 999))
dc.safreq('Q4r2', only=range(0, 999))
dc.safreq('Q4r3', only=range(0, 999))
# Out:
# ## Q4r1 ANSWER DATA CHECK
# # available answer = [0 THRU 999]
# - answer is not error
# ----------
#
# ## Q4r2 ANSWER DATA CHECK
# # available answer = [0 THRU 999]
# - answer is not error
# ----------
#
# ## Q4r3 ANSWER DATA CHECK
# # available answer = [0 THRU 999]
# - answer is not error
# ----------

# %%
dc.df['Q4_max'] = dc.df[['Q4r1', 'Q4r2', 'Q4r3']].max(axis=1)

# %%
# Q4 logic check
idxs = list(dc.df.index)
for idx in idxs :
    max_value = dc.df.loc[idx, 'Q4_max']
    HQ4_value = dc.df.loc[idx, 'HQ4']
    base_qid = f'Q4r{HQ4_value}'
    base_value = dc.df.loc[idx, base_qid]
    if max_value == base_value :
        print(list(dc.df.loc[idx, ['record', base_qid, 'Q4_max']]))
# Out:
# [3, 746, 746]
# [2, 597, 597]
# [8, 937, 937]
# [11, 909, 909]
# [15, 818, 818]
# [16, 813, 813]
# [17, 802, 802]
# [21, 797, 797]
# [22, 439, 439]
# [23, 799, 799]
# [25, 654, 654]
# [26, 821, 821]
# [27, 539, 539]
# [28, 660, 660]
# [30, 974, 974]
# [31, 313, 313]
# [33, 528, 528]
# [38, 897, 897]
# [39, 686, 686]
# [42, 947, 947]
# [46, 791, 791]
# [47, 669, 669]
# [48, 921, 921]
# [51, 950, 950]
# [52, 765, 765]
# [53, 806, 806]
# [56, 553, 553]
# [57, 910, 910]
# [58, 958, 958]
# [62, 999, 999]
# [66, 569, 569]
# [69, 885, 885]
# [70, 863, 863]
# [71, 790, 790]
# [74, 816, 816]
# [76, 567, 567]
# [78, 982, 982]
# [80, 214, 214]
# [81, 568, 568]
# [82, 835, 835]
# [83, 874, 874]
# [86, 528, 528]
# [87, 972, 972]
# [88, 563, 563]
# [91, 967, 967]
# [92, 984, 984]
# [94, 741, 741]
# [97, 951, 951]
# [99, 694, 694]
# [100, 493, 493]
# [101, 864, 864]
# [102, 779, 779]
# [104, 982, 982]
# [105, 890, 890]
# [108, 923, 923]
# [109, 887, 887]
# [110, 846, 846]
# [111, 985, 985]
# ...

# %%
dc.logchk(dc.df.HQ3.isin([1,2,3]), dc.df.HQ4.isin([1, 2]))
# Out:
# ## Puncing Logic Check
# - Puching Logic correct
#
# ----------

# %%
dc.safreq('Q5r1', only=range(0, 99), cond=dc.df.HQ3.isin([1,2,3,4]), err=True)
# Out:
#      record   Q5r1
# 191     371  100.0

# %%
dc.safreq('Q5r2', only=range(0, 99), cond=dc.df.HQ3.isin([3,4,6]), err=True)
# Out:
#      record   Q5r2
# 130     245  100.0

# %%
dc.safreq('Q5r3', only=range(0, 99), cond=dc.df.HQ3.isin([5,6]), err=True)
# Out:
#      record   Q5r3
# 255     494  100.0

# %% [markdown]
# ### Q5 range 0\~100  >  0\~999로 변경

# %%
dc.mafreq(('Q6r1', 'Q6r99'))
dc.safreq('Q6r99', only=99)
Q6_cnt = dc.mafreq(('Q6r1', 'Q6r99'), df=True)[['record', 'count']]
Q6_cnt[Q6_cnt['count']!=1]
# Out:
# ## 'Q6r1 - Q6r99' Answer Check
# # Answer count check
# # atleast error check (atleast = 1)
# atleast - answer is not error
#
# ----------
#
# ## Q6r99 ANSWER DATA CHECK
# # available answer = 99
# - answer is not error
# ----------
# Empty DataFrame
# Columns: [record, count]
# Index: []

# %%
dc.safreq('HQ5')
# Out:
# ## HQ5 MISSING CHECK
# - answer is not missing
# ----------

# %%
dc.df['Q5_max'] = dc.df[['Q5r1', 'Q5r2', 'Q5r3']].max(axis=1)
dc.df[['Q5_max','Q5r1', 'Q5r2', 'Q5r3', 'HQ5']]
# Out:
#      Q5_max   Q5r1   Q5r2   Q5r3  HQ5
# 0      99.0   99.0    NaN    NaN    1
# 1      12.0   12.0    NaN    NaN    1
# 2      96.0   96.0   60.0    NaN    1
# 3      25.0    NaN    NaN   25.0    1
# 4      26.0    NaN    NaN   26.0    1
# 5      84.0   34.0   84.0    NaN    1
# 6      74.0   57.0   74.0    NaN    1
# 7      59.0   59.0    NaN    NaN    1
# 8      28.0   23.0   28.0    NaN    1
# 9       6.0    6.0    NaN    NaN    2
# 10     94.0    NaN    NaN   94.0    1
# 11     84.0   84.0   63.0    NaN    1
# 12     82.0    6.0   82.0    NaN    2
# 13     43.0    NaN    NaN   43.0    1
# 14     92.0   92.0   87.0    NaN    2
# 15     49.0   49.0   16.0    NaN    2
# 16     59.0   59.0    NaN    NaN    2
# 17     80.0    NaN   16.0   80.0    1
# 18     39.0   39.0    NaN    NaN    1
# 19     16.0    NaN    NaN   16.0    2
# 20     85.0    NaN   85.0   20.0    1
# 21     80.0   80.0    NaN    NaN    2
# 22     96.0   96.0    NaN    NaN    1
# 23     97.0   97.0    NaN    NaN    2
# ...

# %% [markdown]
# ### HQ5 rowCond 수정

# %%
dc.count_col('Q6_cnt', ('Q6r1', 'Q6r99'))
dc.df[dc.df.Q6_cnt!=1]['record']
# Out:
# Series([], Name: record, dtype: int64)

# %%
dc.safreq('Q7', only=[1,2,3], cond=dc.df.HQ5==1)
# Out:
# ## Q7 ANSWER DATA CHECK
# # available answer = [1 THRU 3]
# - answer is not error
# ----------

# %%
dc.safreq('Q8x2', only=[1,2,3])
# Out:
# ## Q8x2 ANSWER DATA CHECK
# # available answer = [1 THRU 3]
# - answer is not error
# ----------

# %%
dc.safreq('Q9x1', only=[1,2,3], cond=dc.df.HQ5==2)
# Out:
# ## Q9x1 ANSWER DATA CHECK
# # available answer = [1 THRU 3]
# - answer is not error
# ----------
